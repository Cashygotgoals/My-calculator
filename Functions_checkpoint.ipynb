# %% [markdown]
# <a href="https://colab.research.google.com/github/Cashygotgoals/My-calculator/blob/main/Functions_checkpoint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install streamlit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 70.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 97.4 MB/s eta 0:00:00
# ...

# %%
def calculator (num1, num2):

  operator = input('Enter the operator (+, -, *, /): ')

  if operator == '+':
    result = num1 + num2
    print(f'{num1} + {num2} = {result}')
  elif operator == '-':
    result = num1 - num2
    print(f'{num1} - {num2} = {result}')
  elif operator == '*':
    result = num1 * num2
    print(f'{num1} * {num2} = {result}')
  elif operator == '/':
    if num2 == 0:
      print('Number cannot be divided by 0')
    else:
     result = num1 / num2
     print(f'{num1} / {num2} = {result}')
  else:
    print('Invalid Operator')


while True:
  num1 = int(input('Enter the first number: '))
  num2 = int(input('Enter the second number: '))

  calculator(num1, num2)

  choice = input('Do you want to continue? (y/n) : ')
  if choice.lower() == 'y':
    print("Let's continue")
  else:
    print('You have quit this operation')
    break
# Out:
# Enter the first number: 8
# Enter the second number: 0
# Enter the operator (+, -, *, /): +
# 8 + 0 = 8
# Do you want to continue? (y/n) : n
# You have quit this operation

# %%
# %%writefile calculator.py
import streamlit as st

def calculator(num1, num2, operator):
    if operator == '+':
        return num1 + num2
    elif operator == '-':
        return num1 - num2
    elif operator == '*':
        return num1 * num2
    elif operator == '/':
        if num2 == 0:
            return "Error: Cannot divide by 0"
        else:
            return num1 / num2
    else:
        return "Invalid Operator"

# Streamlit UI
st.title("🧮 Simple Calculator")

num1 = st.number_input("Enter the first number", value=0.0)
num2 = st.number_input("Enter the second number", value=0.0)

operator = st.selectbox("Select an operator", ['+', '-', '*', '/'])

if st.button("Calculate"):
    result = calculator(num1, num2, operator)
    st.success(f"Result: {num1} {operator} {num2} = {result}")
# Out:
# Writing calculator.py

# %% [markdown]
# Method 1: Using streamlit IP address to deploy streamlit apps

# %%
! wget -q -O - ipv4.icanhazip.com
# Out:
# 34.42.60.4

# %%
# Run the streamlit app locally
! streamlit run app.py & npx localtunnel --port 8501
# Out:
# ⠙⠹
# ...
#
# ⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇Need to install the following packages:
# localtunnel@2.0.2
# Ok to proceed? (y)
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.42.60.4:8501
#
# y
#
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴your url is: https://pretty-ghosts-chew.loca.lt
